# %% [markdown]
# # Welcome!
#
# This Jupyter notebook will help you analyze your KidLang data. The coding language that we are using is Python, which is a freely available programming language, used a lot in science. You do not need to understand the code in detail, but it is important that you understand how we analyze and plot the results.
#
# In order to run this code, you will need to enter some variables that are important for correctly finding the experiment on your computer. There will also be a few options that you can set. You can directly edit the text below in order to make these decisions.
#
# Afterwards, click on the boxes in order and click the "Run" button above. This will run the code, and will help you analyze your data. Plots for your results will be displayed below, one-by-one.
#
# This code will walk you through the analysis. Read the text surrounding this code carefully, because it will describe step-by-step what it is doing with your data, and how to interpret the results that you see. We will also ask you questions that you should try to answer by looking at the figures that this code plots.
#
# If you are interested in understanding the code line-by-line, we provide comments (the text after a # symbol) which desecribes the logic behind each step that we take. If you are not, please edit the parts that you are instructed to. Otherwise, you only need to click the 'Run' button above, and everything else will happen automatically!

# %% [markdown]
# First, we need to load your data in from your computer. To do that, please make sure that you have all the data that you need downloaded from Gorilla. Next, go to the
#
# **Edit this block.**

# %%
##############################
#### PLEASE EDIT THESE #######
##############################
# First, we'll need to store the name of your experiment files.
# Tell us the name of your file that corresponds to the comp(osition) first
# task and the list first task. Make sure that they are surrounded by
# single quotes and end in .csv, e.g., 'data_exp_18332-v38_task-hk9d.csv'
compFirstPath = 'compFirst.csv' # First, we'll need to store the name of your experiment files
listFirstPath = 'listFirst.csv' # here; give the name of your file that corresponds to the comp first

############################## 
### DO NOT EDIT AFTER THIS ###
##############################

import csv

directory = 'Datasets'

compFirst = open("Datasets/" + compFirstPath,"r")
compFirst = [i for i in csv.DictReader(compFirst)]
print(compFirst)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
